# %% [markdown]
# # Demo notebook

# %%
from configuration import (
    CLASSIFIER_CONFIGS,
    DATASET_CONFIGS,
    DATASET_CONFIGS_DEMO,
    METRICS_CONFIG,
)
from experiment import run
from inspect_dataset import inspect
from utils import seperate

# %%
dataset_configs = DATASET_CONFIGS_DEMO
num_datasets = len(dataset_configs)

# %%
for config in dataset_configs:
    inspect(config["id"])
# Out:
# ----------------------------------------------------------------------------------------------------
# Dataset Name
# 176: Blood Transfusion Service Center
# ----------------------------------------------------------------------------------------------------
# Metaname
# ...

# %%
seperate(f"Start running experiments on {num_datasets} datasets")
for type in ["supervised", "unsupervised"]:
    run(type, dataset_configs, METRICS_CONFIG, CLASSIFIER_CONFIGS, demo=True)
# Out:
# ----------------------------------------------------------------------------------------------------
# Start running experiments on 1 datasets
# ----------------------------------------------------------------------------------------------------
# Type: supervised learning
# ----------------------------------------------------------------------------------------------------
# List of datasets: [{'id': 176, 'name': 'blood'}]
# ----------------------------------------------------------------------------------------------------
# Dataset: blood
# ----------------------------------------------------------------------------------------------------
# Average score for dataset blood
#                 KNN  RandomForest       SVC
# Accuracy   0.766043      0.737968  0.774064
# F1         0.385257      0.352432  0.248161
# Precision  0.512085      0.430315  0.620833
# Recall     0.310688      0.301781  0.167195
# ...
