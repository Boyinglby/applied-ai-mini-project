# %% [markdown]
# # Notebook for Applied AI mini project

# %%
import pandas as pd
from sklearn import set_config
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score, roc_curve, homogeneity_score, adjusted_rand_score, silhouette_score, v_measure_score

from dataset import Dataset
from configuration import (
    CLASSIFIER_CONFIGS,
    DATASET_CONFIGS,
    DATASET_CONFIGS_DEMO,
    METRICS_CONFIG,
)
from inspect_dataset import inspect
from pipelines import Pipelines
from utils import seperate

# %%
DATASET_IDS = [
    # 22, # Chess (King-Rook vs. King-Pawn)
    70, # Monk's problem
    184 # Acute Inflammations
]
DATASET_ID = 184
CLASSIFIERS = CLASSIFIER_CONFIGS["supervised"]
# Index of target to be used if there are multiple target columns
# e.g., target_col = ['bladder-inflammation', 'nephritis']
# set target_index=0 will use 'bladder-inflammation' as target column
TARGET_INDEX = 0

# %% [markdown]
# ## Data inspection

# %%
inspect(DATASET_ID)
# Out:
# ----------------------------------------------------------------------------------------------------
# Dataset Name
# 184: Acute Inflammations
# ----------------------------------------------------------------------------------------------------
# Metaname
# {'uci_id': 184, 'name': 'Acute Inflammations', 'repository_url': 'https://archive.ics.uci.edu/dataset/184/acute+inflammations', 'data_url': 'https://archive.ics.uci.edu/static/public/184/data.csv', 'abstract': 'The data was created by a medical expert as a data set to test the expert system, \nwhich will perform the presumptive diagnosis of two diseases of the urinary system.\n', 'area': 'Health and Medicine', 'tasks': ['Classification'], 'characteristics': ['Multivariate'], 'num_instances': 120, 'num_features': 6, 'feature_types': ['Categorical', 'Integer'], 'demographics': [], 'target_col': ['bladder-inflammation', 'nephritis'], 'index_col': None, 'has_missing_values': 'no', 'missing_values_symbol': None, 'year_of_dataset_creation': 2003, 'last_updated': 'Tue Apr 16 2024', 'dataset_doi': '10.24432/C5V59S', 'creators': ['Jacek Czerniak'], 'intro_paper': {'ID': 477, 'type': 'NATIVE', 'title': 'Application of rough sets in the presumptive diagnosis of urinary system diseases', 'authors': 'J. Czerniak, H. Zarzycki', 'venue': " ACS'2002 9th International Conference Proceedings", 'year': 2003, 'journal': None, 'DOI': None, 'URL': 'https://www.semanticscholar.org/paper/Application-of-rough-sets-in-the-presumptive-of-Czerniak-Zarzycki/293a271505bbc5db6d68b1429a2bfae9073e88fa', 'sha': None, 'corpus': None, 'arxiv': None, 'mag': None, 'acl': None, 'pmid': None, 'pmcid': None}, 'additional_info': {'summary': "The main idea of this data set is to prepare the algorithm of the expert system, which \r\nwill perform the presumptive diagnosis of two diseases of urinary system. It will be \r\nthe example of diagnosing of the acute inflammations of urinary bladder and acute \r\nnephritises. For better understanding of the problem let us consider definitions of \r\nboth diseases given by medics. Acute inflammation of urinary bladder is characterised \r\nby sudden occurrence of pains in the abdomen region and the urination in form of \r\nconstant urine pushing, micturition pains and sometimes lack of urine keeping. \r\nTemperature of the body is rising, however most often not above 38C. The excreted \r\nurine is turbid and sometimes bloody. At proper treatment, symptoms decay usually \r\nwithin several days. However, there is inclination to returns. At persons with acute \r\ninflammation of urinary bladder, we should expect that the illness will turn into \r\nprotracted form.\r\n\r\nAcute nephritis of renal pelvis origin occurs considerably more often at women than at \r\nmen. It begins with sudden fever, which reaches, and sometimes exceeds 40C. The fever \r\nis accompanied by shivers and one- or both-side lumbar pains, which are sometimes very \r\nstrong. Symptoms of acute inflammation of urinary bladder appear very often. Quite not \r\ninfrequently there are nausea and vomiting and spread pains of whole abdomen.\r\n\r\nThe data was created by a medical expert as a data set to test the expert system, which \r\nwill perform the presumptive diagnosis of two diseases of urinary system.  The basis for \r\nrules detection was Rough Sets Theory.  Each instance represents an potential patient.\r\n\r\nThe data is in an ASCII file. Attributes are separated by TAB.\r\nEach line of the data file starts with a digit which tells the temperature of patient.\r\n\r\n  -- Attribute lines:\r\n       For example, '35,9\tno\tno\tyes\tyes\tyes\tyes\tno'\r\n       Where:\r\n\t '35,9'\tTemperature of patient \t\r\n\t 'no'\tOccurrence of nausea \t\r\n\t 'no'\tLumbar pain  \t\r\n\t 'yes'\tUrine pushing (continuous need for urination)  \t\r\n\t 'yes'\tMicturition pains  \r\n\t 'yes'\tBurning of urethra, itch, swelling of urethra outlet \t\r\n\t 'yes'\tdecision: Inflammation of urinary bladder  \r\n\t 'no'\tdecision: Nephritis of renal pelvis origin ", 'purpose': None, 'funded_by': None, 'instances_represent': None, 'recommended_data_splits': None, 'sensitive_data': None, 'preprocessing_description': None, 'variable_info': ' a1\tTemperature of patient  { 35C-42C }\t\r\n ...
# ----------------------------------------------------------------------------------------------------
# Variable Information
#                    name     role         type demographic description units  \
# 0           temperature  Feature   Continuous        None        None  None
# 1                nausea  Feature  Categorical        None        None  None
# 2           lumbar-pain  Feature  Categorical        None        None  None
# 3         urine-pushing  Feature  Categorical        None        None  None
# 4     micturition-pains  Feature  Categorical        None        None  None
# 5       burning-urethra  Feature  Categorical        None        None  None
# 6  bladder-inflammation   Target  Categorical        None        None  None
# 7             nephritis   Target  Categorical        None        None  None
#
#   missing_values
# 0             no
# 1             no
# 2             no
# 3             no
# 4             no
# 5             no
# 6             no
# 7             no
# ----------------------------------------------------------------------------------------------------
# X
#      temperature nausea lumbar-pain urine-pushing micturition-pains  \
# 0           35.5     no         yes            no                no
# 1           35.9     no          no           yes               yes
# 2           35.9     no         yes            no                no
# 3           36.0     no          no           yes               yes
# 4           36.0     no         yes            no                no
# ..           ...    ...         ...           ...               ...
# 115         41.4     no         yes           yes                no
# 116         41.5     no          no            no                no
# 117         41.5    yes         yes            no               yes
# 118         41.5     no         yes           yes                no
# 119         41.5     no         yes           yes                no
#
#     burning-urethra
# 0                no
# 1               yes
# 2                no
# 3               yes
# 4                no
# ..              ...
# 115             yes
# 116              no
# 117              no
# 118             yes
# 119             yes
#
# [120 rows x 6 columns]
# ----------------------------------------------------------------------------------------------------
# X dtypes
# temperature          float64
# nausea                object
# lumbar-pain           object
# urine-pushing         object
# micturition-pains     object
# burning-urethra       object
# dtype: object
# ----------------------------------------------------------------------------------------------------
# Numeric columns:
# ['temperature']
# ----------------------------------------------------------------------------------------------------
# Non-Numeric columns:
# ['nausea', 'lumbar-pain', 'urine-pushing', 'micturition-pains', 'burning-urethra']
# ----------------------------------------------------------------------------------------------------
# y
#     bladder-inflammation nephritis
# 0                     no        no
# 1                    yes        no
# 2                     no        no
# 3                    yes        no
# 4                     no        no
# ..                   ...       ...
# 115                   no       yes
# 116                   no        no
# 117                   no       yes
# 118                   no       yes
# 119                   no       yes
#
# [120 rows x 2 columns]
# ----------------------------------------------------------------------------------------------------
# y dtypes
# bladder-inflammation    object
# nephritis               object
# dtype: object

# %%
dataset = Dataset(DATASET_ID)
X = dataset.X
y = dataset.y_target
labels = y.unique()

# %%
y.head()
# Out:
# 0     no
# 1    yes
# 2     no
# 3    yes
# 4     no
# Name: bladder-inflammation, dtype: object

# %% [markdown]
# Select the target column

# %% [markdown]
# Encode target

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

X_non_numeric_columns = dataset.categorical_columns
X_numeric_columns = dataset.numeric_columns
print(f"non_numeric_columns: {X_non_numeric_columns}")
print(f"numeric_columns: {X_numeric_columns}")
# Out:
# non_numeric_columns: ['nausea', 'lumbar-pain', 'urine-pushing', 'micturition-pains', 'burning-urethra']
# numeric_columns: ['temperature']

# %% [markdown]
# ## Create pipeline

# %%
pipelines = {}
for classifier_name in CLASSIFIERS:
    pipeline = Pipelines(X_non_numeric_columns, X_numeric_columns, classifier_name).create()
    pipelines[classifier_name] = pipeline

pipelines
# Out:
# {'KNN': Pipeline(steps=[('preprocessing',
#                   ColumnTransformer(transformers=[('categorical',
#                                                    Pipeline(steps=[('imputer_frequent',
#                                                                     SimpleImputer(strategy='most_frequent')),
#                                                                    ('onehot',
#                                                                     OneHotEncoder(handle_unknown='ignore',
#                                                                                   sparse_output=False))]),
#                                                    ['nausea', 'lumbar-pain',
#                                                     'urine-pushing',
#                                                     'micturition-pains',
#                                                     'burning-urethra']),
#                                                   ('numeric',
#                                                    Pipeline(steps=[('imputer_mean',
#                                                                     SimpleImputer()),
#                                                                    ('scaler',
#                                                                     StandardScaler())]),
#                                                    ['temperature'])])),
#                  ('classifier', KNeighborsClassifier())]),
#  'RandomForest': Pipeline(steps=[('preprocessing',
#                   ColumnTransformer(transformers=[('categorical',
#                                                    Pipeline(steps=[('imputer_frequent',
#                                                                     SimpleImputer(strategy='most_frequent')),
#                                                                    ('onehot',
#                                                                     OneHotEncoder(handle_unknown='ignore',
#                                                                                   sparse_output=False))]),
#                                                    ['nausea', 'lumbar-pain',
#                                                     'urine-pushing',
#                                                     'micturition-pains',
#                                                     'burning-urethra']),
#                                                   ('numeric',
#                                                    Pipeline(steps=[('imputer_mean',
#                                                                     SimpleImputer()),
#                                                                    ('scaler',
#                                                                     StandardScaler())]),
#                                                    ['temperature'])])),
#                  ('classifier', RandomForestClassifier())]),
#  'SVC': Pipeline(steps=[('preprocessing',
#                   ColumnTransformer(transformers=[('categorical',
#                                                    Pipeline(steps=[('imputer_frequent',
#                                                                     SimpleImputer(strategy='most_frequent')),
#                                                                    ('onehot',
#                                                                     OneHotEncoder(handle_unknown='ignore',
#                                                                                   sparse_output=False))]),
#                                                    ['nausea', 'lumbar-pain',
#                                                     'urine-pushing',
#                                                     'micturition-pains',
#                                                     'burning-urethra']),
#                                                   ('numeric',
#                                                    Pipeline(steps=[('imputer_mean',
#                                                                     SimpleImputer()),
#                                                                    ('scaler',
#                                                                     StandardScaler())]),
#                                                    ['temperature'])])),
#                  ('classifier', SVC())])}

# %%
# display the pipeline in diagram
set_config(display="diagram")
pipelines.get("KNN")
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(transformers=[('categorical',
#                                                   Pipeline(steps=[('imputer_frequent',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   ['nausea', 'lumbar-pain',
#                                                    'urine-pushing',
#                                                    'micturition-pains',
#                                                    'burning-urethra']),
#                                                  ('numeric',
#                                                   Pipeline(steps=[('imputer_mean',
#                                                                    SimpleImputer()),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['temperature'])])),
#                 ('classifier', KNeighborsClassifier())])

# %%
models = {}
for name, pipe in pipelines.items():
    model = pipe.fit(X_train, y_train)
    models[name] = model

# %%
for name, model in models.items():
    score = model.score(X_test, y_test)
    print(f"Model name: {name}, Score: {score}")
# Out:
# Model name: KNN, Score: 1.0
# Model name: RandomForest, Score: 1.0
# Model name: SVC, Score: 1.0

# %%
def unsupervised_scores(X_test, y_test, models):
    scores = {}
    for name, model in models.items():
        y_pred = model.predict(X_test)
        scores[name] = {
            "homogeneity": accuracy_score(y_test, y_pred),
            "completeness": f1_score(y_test, y_pred),
            "v_measure": recall_score(y_test, y_pred),
            "rand_index": adjusted_rand_score(y_test, y_pred),
            "silhouette": roc_curve(y_test, y_pred)
        }
    return scores

# %%
def evaluate_scores(labels, X_test, y_test, models):
    pos_label = labels[0]
    scores = {}
    for name, model in models.items():
        y_pred = model.predict(X_test)
        accquracy = accuracy_score(y_test, y_pred)
        precision = precision_score(y_test, y_pred, pos_label=pos_label)
        recall = recall_score(y_test, y_pred, pos_label=pos_label)
        f1 = f1_score(y_test, y_pred, pos_label=pos_label)
        scores[name] = [accquracy, precision, recall, f1]
    scores_df = pd.DataFrame(scores, index=["Accuracy", "Precision", "Recall", "F1"])
    return scores_df

# %%
evaluate_scores(labels, X_test, y_test, models)
# Out:
#            KNN  RandomForest  SVC
# Accuracy   1.0           1.0  1.0
# Precision  1.0           1.0  1.0
# Recall     1.0           1.0  1.0
# F1         1.0           1.0  1.0
